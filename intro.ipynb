# %%
# %sql
CREATE CATALOG smart_city_dev

# %%
# %sql
CREATE CATALOG IF NOT EXISTS smart_city_prod

# %%
# %sql
CREATE VOLUME IF NOT EXISTS smart_city_prod.raw

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS smart_city_dev.transportation;
CREATE SCHEMA IF NOT EXISTS smart_city_prod.transportation

# %%
# %sql
CREATE EXTERNAL VOLUME smart_city_dev.transportation.raw
  LOCATION 's3://smartlakehouseproject/dev'
  COMMENT 'The landing zone for raw JSON data from IoT sensors (Dev Environment)';

# %%
# %sql
CREATE EXTERNAL VOLUME smart_city_prod.transportation.raw
  LOCATION 's3://smartlakehouseproject/prod'
  COMMENT 'The landing zone for raw JSON data from IoT sensors (Prod Environment)'

# %%
# %sql

GRANT USE CATALOG ON CATALOG smart_city_prod TO `3f1f9ec9-591e-40d0-8a28-b7d495b444a2`;

# %%
# %sql

GRANT USE SCHEMA ON SCHEMA smart_city_prod.transportation TO `3f1f9ec9-591e-40d0-8a28-b7d495b444a2`;



GRANT CREATE TABLE, CREATE MATERIALIZED VIEW ON SCHEMA smart_city_prod.transportation TO `3f1f9ec9-591e-40d0-8a28-b7d495b444a2`;


GRANT READ VOLUME ON VOLUME smart_city_prod.transportation.raw TO `3f1f9ec9-591e-40d0-8a28-b7d495b444a2`;
